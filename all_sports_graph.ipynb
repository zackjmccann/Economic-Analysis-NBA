# %%
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt

# %%
mlb_csv = pd.read_csv("/Users/samuelgiddins/Desktop/project_one/csv_files/mlb_revenue.csv")

# %%
mlb_df = pd.DataFrame(mlb_csv)

# %%
mlb_df.rename(columns = {"Revenue (Billions USD)": "MLB Revenue (Billions USD)"})
# Out:
#     Year  MLB Revenue (Billions USD)
# 0   2001                        3.58
# 1   2002                        3.65
# 2   2003                        3.88
# 3   2004                        4.27
# 4   2005                        4.73
# 5   2006                        5.11
# 6   2007                        5.48
# 7   2008                        5.82
# 8   2009                        5.90
# 9   2010                        6.14
# 10  2011                        6.36
# 11  2012                        6.81
# 12  2013                        7.10
# 13  2014                        7.86
# 14  2015                        8.39
# 15  2016                        9.03
# 16  2017                        9.46
# 17  2018                        9.90

# %%
nfl_csv = pd.read_csv("/Users/samuelgiddins/Desktop/project_one/csv_files/nfl_revenue.csv")

# %%
nfl_df = pd.DataFrame(nfl_csv)

# %%
nfl_df.rename(columns = {"Revenue (Billions USD)": "NFL Revenue (Billions USD)"})
# Out:
#     Year  NFL Revenue (Billions USD)
# 0   2001                        4.28
# 1   2002                        4.94
# 2   2003                        5.33
# 3   2004                        6.03
# 4   2005                        6.16
# 5   2006                        6.54
# 6   2007                        7.09
# 7   2008                        7.57
# 8   2009                        8.02
# 9   2010                        8.35
# 10  2011                        8.82
# 11  2012                        9.17
# 12  2013                        9.58
# 13  2014                       11.09
# 14  2015                       12.16
# 15  2016                       13.16
# 16  2017                       13.68

# %%
nhl_csv = pd.read_csv("/Users/samuelgiddins/Desktop/project_one/csv_files/nhl_revenue.csv")

# %%
nhl_df = pd.DataFrame(nhl_csv)

# %%
nhl_df.rename(columns = {"Revenue (Billions USD)": "NHL Revenue (Billions USD)"})
# Out:
#     Year  NHL Revenue (Billions USD)
# 0   2005                        2.27
# 1   2006                        2.44
# 2   2007                        2.75
# 3   2008                        2.82
# 4   2009                        2.93
# 5   2010                        3.09
# 6   2011                        3.37
# 7   2012                        2.63
# 8   2013                        3.70
# 9   2014                        3.98
# 10  2015                        4.10
# 11  2016                        4.43
# 12  2017                        4.86

# %%
merge1 = pd.merge(mlb_df, nfl_df, how="left", on="Year")

# %%
sports_df = pd.merge(merge1, nhl_df, how="left", on="Year")

# %%
sports_df.rename(columns = {"Revenue (Billions USD)_x": "MLB Revenue (Billions USD)", "Revenue (Billions USD)_y": "NFL Revenue (Billions USD)", "Revenue (Billions USD)": "NHL Revenue (Billions USD)"})
# Out:
#     Year  MLB Revenue (Billions USD)  NFL Revenue (Billions USD)  \
# 0   2001                        3.58                        4.28
# 1   2002                        3.65                        4.94
# 2   2003                        3.88                        5.33
# 3   2004                        4.27                        6.03
# 4   2005                        4.73                        6.16
# 5   2006                        5.11                        6.54
# 6   2007                        5.48                        7.09
# 7   2008                        5.82                        7.57
# 8   2009                        5.90                        8.02
# 9   2010                        6.14                        8.35
# 10  2011                        6.36                        8.82
# 11  2012                        6.81                        9.17
# 12  2013                        7.10                        9.58
# 13  2014                        7.86                       11.09
# 14  2015                        8.39                       12.16
# 15  2016                        9.03                       13.16
# 16  2017                        9.46                       13.68
# 17  2018                        9.90                         NaN
#
#     NHL Revenue (Billions USD)
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                         2.27
# 5                         2.44
# 6                         2.75
# 7                         2.82
# 8                         2.93
# 9                         3.09
# 10                        3.37
# 11                        2.63
# 12                        3.70
# 13                        3.98
# 14                        4.10
# 15                        4.43
# 16                        4.86
# 17                         NaN

# %%
final_sports_df = sports_df.reset_index()

# %%
final_sports_df["Year"]
# Out:
# 0     2001
# 1     2002
# 2     2003
# 3     2004
# 4     2005
# 5     2006
# 6     2007
# 7     2008
# 8     2009
# 9     2010
# 10    2011
# 11    2012
# 12    2013
# 13    2014
# 14    2015
# 15    2016
# 16    2017
# 17    2018
# Name: Year, dtype: int64

# %%
#Create the Scatter plot
sport_list = ['MLB', 'NFL', 'NHL']
year_list = ['June 2002', 'January 2005', 'June 2007', 'January 2010', 'June 2012', 'January 2015', 'June 2017']
plt.plot(final_sports_df["Year"], final_sports_df["Revenue (Billions USD)_x"], color="r", marker="o", linestyle="dashed", linewidth=1)
plt.plot(final_sports_df["Year"], final_sports_df["Revenue (Billions USD)_y"], color="b", marker="o", linestyle="dashed", linewidth=1)
plt.plot(final_sports_df["Year"],final_sports_df["Revenue (Billions USD)"], color="g", marker="o", linestyle="dashed", linewidth=1)
plt.grid(True)
plt.title("Major Sports League Revenues")
plt.xlabel("Year") 
plt.xticks(final_sports_df["Year"], rotation=45, ha="right")
plt.ylabel("Revenue (Billions USD)")
plt.figlegend(sport_list)

plt.show()
